# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanask/Python_basics_practise/blob/main/Python_DS_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Salaries.csv")
df
type (df)
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#to view first five records in our data frame
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.tail(15)
# Out:
#          rank discipline  phd  service     sex  salary
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option("display.max_rows",77)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1b0e7e2408d8> in <cell line: 1>()
# ----> 1 pd.set_option("display.max_rows",77)
#       2 df
#
# NameError: name 'pd' is not defined

# %%
pd.set_option("display.max_rows", None)
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.notnull()
# Out:
#     rank  discipline   phd  service   sex  salary
# 0   True        True  True     True  True    True
# 1   True        True  True     True  True    True
# 2   True        True  True     True  True    True
# 3   True        True  True     True  True    True
# 4   True        True  True     True  True    True
# 5   True        True  True     True  True    True
# 6   True        True  True     True  True    True
# 7   True        True  True     True  True    True
# 8   True        True  True     True  True    True
# 9   True        True  True     True  True    True
# 10  True        True  True     True  True    True
# 11  True        True  True     True  True    True
# 12  True        True  True     True  True    True
# 13  True        True  True     True  True    True
# 14  True        True  True     True  True    True
# 15  True        True  True     True  True    True
# 16  True        True  True     True  True    True
# 17  True        True  True     True  True    True
# ...

# %%
import pandas as pd
df= pd.read_csv("Salaries.csv")


df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# ...

# %%
df.mean()
# Out:
# <ipython-input-43-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")
df.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode(

)
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427907

# %%
df['salary'].std()
# Out:
# 28293.66102226417

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].max(

)
# Out:
# 186960

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df[['salary','service']]
# Out:
#     salary  service
# 0   186960       49
# 1    93000        6
# 2   110515       20
# 3   131205       31
# 4   104800       18
# 5   122400       20
# 6    81285       17
# 7   126300       18
# 8    94350       19
# 9    57800       51
# 10  128250       33
# 11  134778       23
# 12   88000        0
# 13  162200       33
# 14  153750       19
# 15  150480        3
# 16   75044        3
# 17   92000        0
# 18  107300        7
# 19  150500       27
# 20   92000        4
# 21  103106       30
# 22   73000        2
# 23   85000        0
# 24   91100       23
# 25   99418       31
# 26  148750       19
# 27  155865       43
# 28   91300        2
# 29  123683       20
# 30  107008        7
# 31  155750       21
# 32  103275       19
# 33  120000       18
# 34  119800        8
# 35  126933       23
# 36  146856       45
# 37  102000        8
# 38   91000        3
# 39  129000       18
# 40  137000       36
# 41   74830        8
# 42   80225        2
# 43   77000        0
# ...

# %%
df[['salary','service','phd']]
# Out:
#     salary  service  phd
# 0   186960       49   56
# 1    93000        6   12
# 2   110515       20   23
# 3   131205       31   40
# 4   104800       18   20
# 5   122400       20   20
# 6    81285       17   20
# 7   126300       18   18
# 8    94350       19   29
# 9    57800       51   51
# 10  128250       33   39
# 11  134778       23   23
# 12   88000        0    1
# 13  162200       33   35
# 14  153750       19   25
# 15  150480        3   17
# 16   75044        3    8
# 17   92000        0    4
# 18  107300        7   19
# 19  150500       27   29
# 20   92000        4    4
# 21  103106       30   33
# 22   73000        2    4
# 23   85000        0    2
# 24   91100       23   30
# 25   99418       31   35
# 26  148750       19   38
# 27  155865       43   45
# 28   91300        2    7
# 29  123683       20   21
# 30  107008        7    9
# 31  155750       21   22
# 32  103275       19   27
# 33  120000       18   18
# 34  119800        8   12
# 35  126933       23   28
# ...

# %%
df[['salary','service','phd']].mean()
# Out:
# salary     108023.782051
# service        15.051282
# phd            19.705128
# dtype: float64

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:50,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:50,0:4]
# Out:
#          rank discipline  phd  service
# 0        Prof          B   56       49
# 1        Prof          A   12        6
# 2        Prof          A   23       20
# 3        Prof          A   40       31
# 4        Prof          B   20       18
# 5        Prof          A   20       20
# 6   AssocProf          A   20       17
# 7        Prof          A   18       18
# 8        Prof          A   29       19
# 9        Prof          A   51       51
# 10       Prof          B   39       33
# 11       Prof          B   23       23
# 12   AsstProf          B    1        0
# 13       Prof          B   35       33
# 14       Prof          B   25       19
# 15       Prof          B   17        3
# 16   AsstProf          B    8        3
# 17   AsstProf          B    4        0
# 18       Prof          A   19        7
# 19       Prof          A   29       27
# 20   AsstProf          B    4        4
# 21       Prof          A   33       30
# 22   AsstProf          A    4        2
# ...

# %%
df.iloc[0:50,[0,2,4,4]]
# Out:
#          rank  phd     sex     sex
# 0        Prof   56    Male    Male
# 1        Prof   12    Male    Male
# 2        Prof   23    Male    Male
# 3        Prof   40    Male    Male
# 4        Prof   20    Male    Male
# 5        Prof   20    Male    Male
# 6   AssocProf   20    Male    Male
# 7        Prof   18    Male    Male
# 8        Prof   29    Male    Male
# 9        Prof   51    Male    Male
# 10       Prof   39    Male    Male
# 11       Prof   23    Male    Male
# 12   AsstProf    1    Male    Male
# 13       Prof   35    Male    Male
# 14       Prof   25    Male    Male
# 15       Prof   17    Male    Male
# 16   AsstProf    8    Male    Male
# 17   AsstProf    4    Male    Male
# 18       Prof   19    Male    Male
# 19       Prof   29    Male    Male
# 20   AsstProf    4    Male    Male
# 21       Prof   33    Male    Male
# 22   AsstProf    4    Male    Male
# 23   AsstProf    2    Male    Male
# 24       Prof   30    Male    Male
# 25       Prof   35    Male    Male
# ...

# %%
df.iloc[0:50,[0,1,3,4]]
# Out:
#          rank discipline  service     sex
# 0        Prof          B       49    Male
# 1        Prof          A        6    Male
# 2        Prof          A       20    Male
# 3        Prof          A       31    Male
# 4        Prof          B       18    Male
# 5        Prof          A       20    Male
# 6   AssocProf          A       17    Male
# 7        Prof          A       18    Male
# 8        Prof          A       19    Male
# 9        Prof          A       51    Male
# 10       Prof          B       33    Male
# 11       Prof          B       23    Male
# 12   AsstProf          B        0    Male
# 13       Prof          B       33    Male
# 14       Prof          B       19    Male
# 15       Prof          B        3    Male
# 16   AsstProf          B        3    Male
# 17   AsstProf          B        0    Male
# 18       Prof          A        7    Male
# 19       Prof          A       27    Male
# 20   AsstProf          B        4    Male
# ...

# %%
df.loc[0,'salary']
# Out:
# 186960

# %%
df1 = pd.read_csv('Salaries.csv', nrows=1)
df1
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960

# %%
df.salary>120000
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28    False
# 29     True
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39     True
# 40     True
# 41    False
# 42    False
# 43    False
# 44     True
# 45     True
# 46    False
# 47    False
# 48    False
# 49     True
# 50    False
# 51     True
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
df['salary']>120000
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28    False
# 29     True
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39     True
# 40     True
# 41    False
# 42    False
# 43    False
# 44     True
# 45     True
# 46    False
# 47    False
# 48    False
# 49     True
# 50    False
# 51     True
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df.groupby(['rank']).mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
import pandas as pd
df = pd.read_csv("Salaries.csv")
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv("Universities.csv")

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df['Accept'])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['SAT'])
plt.title("Histogram of SAT")
plt.xlabel('SAT Score')
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(df['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
sns.histplot(df['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
plt.plot(df['SAT'], df["Accept"], 'rs')

# %%
plt.plot(df['SAT'], df['Accept'], 'rs')
plt.title('SCATTER PLOT BETWWEN SAT AND ACCEPT')
plt.xlabel('SAT')
plt.ylabel('Accept')
# Out:
# Text(0, 0.5, 'Accept')

# %%
sns.scatterplot(x='SAT', y='Accept', data=df)
# Out:
# <Axes: xlabel='SAT', ylabel='Accept'>

# %%
sns.distplot(df['Accept'])
# Out:
# <ipython-input-24-6803a7d836ab>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Accept'])
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
sns.distplot(df['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Density'>

# %%
sns.distplot(df['Top10'])
# Out:
# <Axes: xlabel='Top10', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
sns.displot(df.iloc[:,1:4])

# %%
sns.pairplot(df.iloc[:,1:4])

# %%
plt.boxplot(df['SAT'])
plt.show()

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
plt.boxplot(df['SAT'], vert= 'FALSE')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c73d1d98d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c73d1d99270>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c73d1d98a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c73d1d988e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c73d1d99660>],
#  'means': []}

# %% [markdown]
# ***"Pandas Concepts"***

# %%
import numpy as np
a = np.array([(1,2,3,4), (5,6,7,8)])

# %%
print(a)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (2, 4)

# %%
a.size
# Out:
# 8

# %%
a[0,2]
# Out:
# 3

# %%
a[1,2]
# Out:
# 7

# %%
b= a.reshape(4,2)

# %%
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %%
c = np.array([1,2,3,4])

# %%
c
# Out:
# array([1, 2, 3, 4])

# %%
c.shape
# Out:
# (4,)

# %%
c.sum()
# Out:
# 10

# %%
c.prod()
# Out:
# 24

# %%
c.min()
# Out:
# 1

# %%
c.max()
# Out:
# 4

# %%
d = np.array([(1,2,3,4), (5,6,7,8)])

# %%
print(d)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
d.sum(axis=0)
# Out:
# array([ 6,  8, 10, 12])

# %%
d.sum(axis=1)
# Out:
# array([10, 26])

# %%
dup=pd.DataFrame({'col1':['A','A','B','B','B'],'col2':[2,2,2,3,3]})

# %%
dup
# Out:
#   col1  col2
# 0    A     2
# 1    A     2
# 2    B     2
# 3    B     3
# 4    B     3

# %%
dup.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
dup[dup.duplicated()]
# Out:
#   col1  col2
# 1    A     2
# 4    B     3

# %%
dup1 = dup.drop_duplicates()

# %%
dup1
# Out:
#   col1  col2
# 0    A     2
# 2    B     2
# 3    B     3

# %%
dup = dup1.reset_index()

# %%
dup
# Out:
#    index col1  col2
# 0      0    A     2
# 1      2    B     2
# 2      3    B     3

# %%
dup3 = dup.drop('index', axis=1)

# %%
dup3
# Out:
#   col1  col2
# 0    A     2
# 1    B     2
# 2    B     3

# %%
a = [1,2,3,4]

# %%
type(a)
# Out:
# list

# %%
b = pd.Series(a)

# %%
b
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
snacks = ['pizza','burger','shawarma','franky','sandwitch']
snacks
# Out:
# ['pizza', 'burger', 'shawarma', 'franky', 'sandwitch']

# %%
pd.Series(snacks)
# Out:
# 0        pizza
# 1       burger
# 2     shawarma
# 3       franky
# 4    sandwitch
# dtype: object

# %%
days=['Monday','Tuesday','Wednesday','Thursday','Firday']
days
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Firday']

# %%
pd.Series(data=snacks,index=days)
# Out:
# Monday           pizza
# Tuesday         burger
# Wednesday     shawarma
# Thursday        franky
# Firday       sandwitch
# dtype: object

# %%
dict={'a':10,'b':20,'c':30,'d':40}
dict
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
pd.Series(dict)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
